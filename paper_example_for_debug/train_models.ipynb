# %%
# ruff: noqa
import sys, os
sys.path.append(os.path.abspath("./../feedback-grape"))
sys.path.append(os.path.abspath("./../"))

# ruff: noqa
from feedback_grape.fgrape import optimize_pulse
from helpers import (
    init_fgrape_protocol,
    test_implementations,
    generate_superposition_state,
    experiment_param_formats,
)
from library.utils.FgResult_to_dict import FgResult_to_dict
import json, jax
import jax.numpy as jnp

test_implementations()

# %%
# Training and evaluation parameters
dir_ = "./02_results"

training_params = {
    "N_samples": 1, # Number of random initial states to sample
    "samples_offset": 0, # Offset for sample indexing
    "learning_rate": 0.01, # Learning rate
    "convergence_threshold": 1e-6,
    "batch_size": 8,
    "eval_batch_size": 128,
    "evaluation_time_steps": 20,
    "use_numeric_decay": True,
}

# Physical Parameters to test

#num_time_steps : Number of time steps in the control pulse
#lut_memory : Amount of measurements the LUT remembers (depth of LUT)
#reward_weights : Weights for the reward at each time step. Default only weights last timestep [0, 0, ... 0, 1]
#N_qubits : Number of parallel chains to simulate
#experiments = [ # (timesteps, reward_weights, N_qubits, N_meas, gamma_z, gamma_m, Ntrainiter, rnnhsize)
#    (2, [1,1], N_qubits, N_qubits-1, 0.1, 0.1, 10000, rnnhsize)
#    for N_qubits in [4, 5, 6]
#    for rnnhsize in [8, 16, 32, 64, 128, 256]
#]
experiments = [(1, [1], 1, 1, 0.1, 0.1, 10000, 0)]

# Check if directory structure exists, create if not
for dir__ in [dir_, f"{dir_}/models", f"{dir_}/training_params"]:
    os.makedirs(dir__, exist_ok=True)

# Generate parameter-based file paths
def generate_param_paths(dir_, params, s):
    parts = []
    for (name, param_type), param in zip(experiment_param_formats, params):
        assert type(param) == param_type, f"Parameter {name} has type {type(param)}, expected {param_type}."
        if type(param) == list:
            param_str = "".join(str(x) for x in param)
        else:
            param_str = str(param)
        parts.append(f"{name}={param_str}")

    pstr = "_".join(parts)
    pstr += f"_s={s}"
    
    return (
        f"{dir_}/models/{pstr}.json",
        f"{dir_}/training_params/{pstr}.json",
    )

# %%
def run_experiment(params):
    (
        num_time_steps,
        reward_weights,
        N_qubits,
        N_meas,
        gamma_z,
        gamma_m,
        N_training_iterations,
        rnn_hidden_size,
    ) = params
    
    print(f"Evaluating {params}")
    rho = generate_superposition_state(N_qubits)

    for s in range(training_params["samples_offset"], training_params["N_samples"] + training_params["samples_offset"]):
        path1, path2 = generate_param_paths(dir_, params, s)
        #if os.path.exists(path1):
        #    print(f"Skipping existing experiment for params {params} and seed {s}.")
        #    continue

        with open(path2, "w") as f:
            json.dump(training_params, f)

        system_params = init_fgrape_protocol(
            jax.random.PRNGKey(s),
            N_qubits,
            N_meas,
            gamma_z,
            gamma_m,
            use_numeric_decay=training_params["use_numeric_decay"],
        )

        # Train RNN
        result = optimize_pulse(
            U_0=rho,
            C_target=rho,
            system_params=system_params,
            num_time_steps=num_time_steps,
            reward_weights=reward_weights,
            mode="lookup",
            goal="fidelity",
            max_iter=N_training_iterations,
            convergence_threshold=training_params["convergence_threshold"],
            learning_rate=training_params["learning_rate"],
            evo_type="density",
            batch_size=training_params["batch_size"],
            eval_batch_size=training_params["eval_batch_size"],
            eval_time_steps=training_params["evaluation_time_steps"],
            progress=True,
            #rnn_hidden_size=rnn_hidden_size,
        )

        print(f"Iterations: {result.iterations}, Average fidelity over 5 timesteps: {jnp.mean(jnp.mean(jnp.array(result.fidelity_each_timestep), axis=1)[1:6]):.2f}")

        with open(path1, "w") as f:
            json.dump(FgResult_to_dict(result), f)

        del result  # Free memory
        del system_params  # Free memory

for params in experiments:
    run_experiment(params)
# Out:
# Evaluating (1, [1], 1, 1, 0.1, 0.1, 10000, 0)
# Iteration 10, Loss: -0.272882, T=0s, eta=54s
# Iteration 20, Loss: -0.109361, T=0s, eta=34s
# Iteration 30, Loss: -0.219992, T=0s, eta=26s
# Iteration 40, Loss: -0.301000, T=0s, eta=22s
# Iteration 50, Loss: -0.374232, T=0s, eta=20s
# Iteration 60, Loss: -0.372612, T=0s, eta=18s
# Iteration 70, Loss: -0.308177, T=0s, eta=17s
# Iteration 80, Loss: -0.310861, T=0s, eta=17s
# Iteration 90, Loss: -0.345322, T=0s, eta=16s
# Iteration 100, Loss: -0.377902, T=0s, eta=16s
# Iteration 110, Loss: -0.312166, T=0s, eta=15s
# Iteration 120, Loss: -0.312291, T=0s, eta=15s
# Iteration 130, Loss: -0.312156, T=0s, eta=14s
# Iteration 140, Loss: -0.332864, T=0s, eta=14s
# Iteration 150, Loss: -0.308691, T=0s, eta=14s
# Iteration 160, Loss: -0.297621, T=0s, eta=14s
# Iteration 170, Loss: -0.305887, T=0s, eta=13s
# Iteration 180, Loss: -0.302424, T=0s, eta=13s
# Iteration 190, Loss: -0.292435, T=0s, eta=13s
# Iteration 200, Loss: -0.332316, T=0s, eta=13s
# Iteration 210, Loss: -0.320895, T=0s, eta=13s
# Iteration 220, Loss: -0.341762, T=0s, eta=13s
# Iteration 230, Loss: -0.386704, T=0s, eta=13s
# Iteration 240, Loss: -0.391791, T=0s, eta=12s
# Iteration 250, Loss: -0.302335, T=0s, eta=12s
# Iterations: 252, Average fidelity over 5 timesteps: 0.89
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 63
#      60         del system_params  # Free memory
#      62 for params in experiments:
# ---> 63     run_experiment(params)
#
# Cell In[3], line 57, in run_experiment(params)
#      54 print(f"Iterations: {result.iterations}, Average fidelity over 5 timesteps: {jnp.mean(jnp.mean(jnp.array(result.fidelity_each_timestep), axis=1)[1:6]):.2f}")
#      56 with open(path1, "w") as f:
# ---> 57     json.dump(FgResult_to_dict(result), f)
#      59 del result  # Free memory
#      60 del system_params
#
# File ~/Documents/Forschungsprojekt III/code/library/utils/FgResult_to_dict.py:18, in FgResult_to_dict(result)
#      14 def FgResult_to_dict(result):
#      15     data = {
#      16         "iterations": result.iterations,
#      17         #"returned_params": __to_serializable(result.returned_params), # Removed because it takes too much space
# ---> 18         "final_fidelity": float(result.final_fidelity) if type(result.final_fidelity) != NoneType else -1,
#      19         "final_purity":  float(result.final_purity) if type(result.final_purity) != NoneType else -1,
#      20         "optimized_trainable_parameters": __to_serializable(result.optimized_trainable_parameters),
#      21         "fidelity_each_timestep": __to_serializable(np.array(result.fidelity_each_timestep)),
#      22         #"state_each_timestep_real": __to_serializable(np.real(np.array(result.state_each_timestep))), # Removed because it takes too much space
#      23         #"state_each_timestep_imag": __to_serializable(np.imag(np.array(result.state_each_timestep))),
#      24     }
#      26     return data
#
# File ~/Documents/Forschungsprojekt III/code/.venv/lib/python3.13/site-packages/jax/_src/array.py:349, in ArrayImpl.__float__(self)
#     348 def __float__(self):
# --> 349   core.check_scalar_conversion(self)
#     350   return self._value.__float__()
#
# File ~/Documents/Forschungsprojekt III/code/.venv/lib/python3.13/site-packages/jax/_src/core.py:705, in check_scalar_conversion(arr)
#     703 def check_scalar_conversion(arr: Array):
#     704   if arr.ndim > 0:
# --> 705     raise TypeError("Only scalar arrays can be converted to Python scalars; "
#     706                     f"got {arr.ndim=}")
#
# TypeError: Only scalar arrays can be converted to Python scalars; got arr.ndim=1
