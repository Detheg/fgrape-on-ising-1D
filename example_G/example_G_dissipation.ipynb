# %% [markdown]
# ### Perfect Quantum State Transfer in 1D qubit chain
# This notebook implements the second proposed system in [1] "Perfect State Transfer in Quantum Spin Networks" from 2004. This paper predicts that on a $n$-qubit chain with arbitrary $N$ and $\sigma^+$ $\sigma^-$ nearest neighbor couplings an excited state can perfectly be transferred from the first qubit to the last in a single timestep when the coupling parameters $J_i$ are chosen according to $J_i = \sqrt{i(n-i)}$. Note, that we chose the parameter $\lambda$ to be $\lambda=2$. The overlap of the state after time evolution and the target state (with the $n$-th spin up) is $F = (-i)^{(n-1)}$ where $i$ is the imaginary unit (eq. 15 in [1]). To compensate for this phase, we added a phase term to the Hamilonian.

# %%
# Add the feedback-grape git submodule to the path
import sys, os
sys.path.append(os.path.abspath("./../feedback-grape"))
sys.path.append(os.path.abspath("./../"))

from feedback_grape.utils.operators import (
    sigmap,
    sigmam,
)
from feedback_grape.utils.states import basis
from feedback_grape.utils.tensor import tensor
from feedback_grape.fgrape import optimize_pulse, Gate, Decay
import jax
from jax import numpy as jnp
from library.utils.qubit_chain_1D import embed
from tqdm import tqdm
from jax.scipy.linalg import expm
from matplotlib import pyplot as plt

# Training parameters
N_samples = 5 # Number of random initializations to test
N_training_iterations = 100 # Number of training iterations
learning_rate = 0.02 # Learning rate
alphas = jnp.linspace(0, 1, 5) # Coefficients for initial superposition state
phis = jnp.linspace(0, 2*jnp.pi, 4)

# System parameters
n = 6 # Number of qubits
i = 0 # qubit state to be transferred (n=4, i=0 is the example from the paper)

def prepare_state(alpha, phi, n):
    # Initial state with superposition on qubit 0 on n-qubit chain
    beta = (1 - alpha**2)**0.5 * jnp.exp(1j*phi) # coefficient for initial state on qubit i
    psi_i = alpha*basis(2,1) + beta*basis(2,0) # assume spin down, repr. as (0, 1), is |g> and spin up (1, 0) is |e>
    
    def place_at_Qi(psi, i, n):
        return tensor(*[basis(2, 1)]*i, psi, *[basis(2, 1)]*(n-i-1))
    
    psi_initial = place_at_Qi(psi_i, i, n)    # Q_i in state |psi_i>, all others in |g>

    psi_initial /= jnp.linalg.norm(psi_initial)

    rho_initial = psi_initial @ psi_initial.conj().T

    return rho_initial

# Control operators (sigmam, sigmap between neighboring qubits)
def transport_hamiltonian(params):
    H_I = sum([
        g_prime_j*embed(sigmap(), j, n)@embed(sigmam(), j+1, n)
        for j,g_prime_j in enumerate(params)
    ])
    H_I = H_I + H_I.conj().T

    # Need another phase of i^(n-1) for basis vectors with one spin up. (c.f. eq 15 in [1])
    # Hence we add a term with eigenvalue -1 for all those vectors to Homiltonian.
    # When evolving for time tau = pi/2, this adds a exp(-1j*pi/2*(-1)) = i.
    # We multiply by ((n - 1) % 4), to get the desired i^(n-1) term.
    H_phase = - sum([embed(jnp.array([[1,0],[0,0]]), j, n) for j in range(n)]) * ((n - 1) % 4)
    
    return H_I

J_theory = jnp.array([(j*(n-j))**0.5 for j in range(1, n)]) # Theory couplings from paper
half_transport = expm(-1j*jnp.pi/4 * transport_hamiltonian(J_theory)) # Half transport unitary


def initialize_transport_gates(key):
    return Gate(
        gate = transport_unitary,
        initial_params=jax.random.uniform(
            jax.random.PRNGKey(key),
            shape=(n-1,), # n-1 couplings
            minval=0.0,
            maxval=n,
            dtype=float,
        ),
        param_constraints = [(0.0, 2*n)]*(n-1), # constraints for each coupling
        measurement_flag=False,
    )


# Test theory coupling strengths
from feedback_grape.utils.fidelity import fidelity

def theory_J(j, n):
    return (j*(n-j))**0.5

J_theory = jnp.array([theory_J(j+1, n) for j in range(n-1)])
for alpha in alphas:
    for phi in phis:
        rho_initial, rho_target = prepare_states(alpha, phi, i, n)

        U = transport_unitary(J_theory)
        rho_final = U @ rho_initial @ U.conj().T
        
        fidelity_value = fidelity(C_target=rho_target, U_final=rho_final, evo_type="unitary")
        print(f"Fidelity for alpha={alpha:.2f}, phi={phi:.2f}: {fidelity_value:.2f}")
# Out:
# Fidelity for alpha=0.00, phi=0.00: 1.00
# Fidelity for alpha=0.00, phi=2.09: 1.00
# Fidelity for alpha=0.00, phi=4.19: 1.00
# Fidelity for alpha=0.00, phi=6.28: 1.00
# Fidelity for alpha=0.25, phi=0.00: 1.00
# Fidelity for alpha=0.25, phi=2.09: 1.00
# Fidelity for alpha=0.25, phi=4.19: 1.00
# Fidelity for alpha=0.25, phi=6.28: 1.00
# Fidelity for alpha=0.50, phi=0.00: 1.00
# Fidelity for alpha=0.50, phi=2.09: 1.00
# Fidelity for alpha=0.50, phi=4.19: 1.00
# Fidelity for alpha=0.50, phi=6.28: 1.00
# Fidelity for alpha=0.75, phi=0.00: 1.00
# Fidelity for alpha=0.75, phi=2.09: 1.00
# Fidelity for alpha=0.75, phi=4.19: 1.00
# Fidelity for alpha=0.75, phi=6.28: 1.00
# Fidelity for alpha=1.00, phi=0.00: 1.00
# Fidelity for alpha=1.00, phi=2.09: 1.00
# Fidelity for alpha=1.00, phi=4.19: 1.00
# Fidelity for alpha=1.00, phi=6.28: 1.00

# %%
fidelity_lists  = []
fidelity_labels = []

best_result_each = []

for alpha in alphas:
    for phi in phis:
        print(f"Running for alpha={alpha:.2f}, phi={phi:.2f}", end="...")

        best_result = None
        fidelity_list = []

        rho_initial, rho_target = prepare_states(alpha, phi, i, n)

        for s in range(N_samples):
            # Initialize time evolution operators (only transport)
            system_params = [initialize_transport_gates(key=s)]

            # Training
            result = optimize_pulse(
                U_0=rho_initial,
                C_target=rho_target,
                system_params=system_params,
                num_time_steps=1,
                mode="no-measurement",
                goal="fidelity",
                max_iter=N_training_iterations,
                convergence_threshold=1e-6,
                learning_rate=learning_rate,
                evo_type="density",
                batch_size=8,
                eval_batch_size=10,
            )

            if best_result is None or result.final_fidelity > best_result.final_fidelity:
                best_result = result

            fidelity_list.append(result.final_fidelity)

        print(f" Best fidelity: {max(fidelity_list):.2f}. Iterations: {best_result.iterations}")
        fidelity_lists.append(fidelity_list)
        fidelity_labels.append(f"alpha={alpha:.2f} phi = {phi:.2f}")
        best_result_each.append(best_result)
# Out:
# Running for alpha=0.00, phi=0.00...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[113], line 20
#      17 system_params = [initialize_transport_gates(key=s)]
#      19 # Training
# ---> 20 result = optimize_pulse(
#      21     U_0=rho_initial,
#      22     C_target=rho_target,
#      23     system_params=system_params,
#      24     num_time_steps=1,
#      25     mode="no-measurement",
#      26     goal="fidelity",
#      27     max_iter=N_training_iterations,
#      28     convergence_threshold=1e-6,
#      29     learning_rate=learning_rate,
#      30     evo_type="density",
#      31     batch_size=8,
#      32     eval_batch_size=10,
#      33 )
#      35 if best_result is None or result.final_fidelity > best_result.final_fidelity:
#      36     best_result = result
#
# File ~/Documents/Forschungsprojekt III/code/feedback-grape/feedback_grape/fgrape.py:778, in optimize_pulse(U_0, C_target, system_params, num_time_steps, max_iter, convergence_threshold, learning_rate, evo_type, lut_depth, reward_weights, goal, batch_size, eval_batch_size, mode, rnn, rnn_hidden_size, progress)
#     774     return loss_sum1 + loss_sum2
#     776 train_key, eval_key = jax.random.split(train_eval_key)
# --> 778 best_model_params, iter_idx = _train(
#     779     loss_fn=loss_fn,
#     780     trainable_params=trainable_params,
#     781     max_iter=max_iter,
#     782     learning_rate=learning_rate,
#     783     convergence_threshold=convergence_threshold,
#     784     prng_key=train_key,
#     785     progress=progress,
#     786     early_stop=early_stop,
#     787 )
#     789 result = _evaluate(
#     790     U_0=U_0,
#     791     C_target=C_target,
#    (...)    807     num_iterations=iter_idx,
#     808 )
#     810 return result
#
# File ~/Documents/Forschungsprojekt III/code/feedback-grape/feedback_grape/fgrape.py:828, in _train(loss_fn, trainable_params, prng_key, max_iter, learning_rate, convergence_threshold, progress, early_stop)
#     823 """
#     824 Train the model using the specified optimizer.
#     825 """
#     826 # Optimization
#     827 # set up optimizer and training state
# --> 828 best_model_params, iter_idx = optimize_adam_feedback(
#     829     loss_fn,
#     830     trainable_params,
#     831     max_iter,
#     832     learning_rate,
#     833     convergence_threshold,
#     834     prng_key,
#     835     progress,
#     836     early_stop,
#     837 )
#     839 # Due to the complex parameter l-bfgs is very slow and leads to bad results so is omitted
#     841 return best_model_params, iter_idx
#
# File ~/Documents/Forschungsprojekt III/code/feedback-grape/feedback_grape/utils/optimizers.py:60, in optimize_adam_feedback(loss_fn, control_amplitudes, max_iter, learning_rate, convergence_threshold, key, progress, early_stop)
#      56 losses.append(loss)
#      57 if early_stop:
#      58     if (
#      59         iter_idx > 0
# ---> 60         and abs(losses[-1] - losses[-2]) < convergence_threshold
#      61     ):
#      62         break
#      64 if progress:
#
# File ~/Documents/Forschungsprojekt III/code/.venv/lib/python3.13/site-packages/jax/_src/array.py:346, in ArrayImpl.__bool__(self)
#     344 def __bool__(self):
#     345   core.check_bool_conversion(self)
# --> 346   return bool(self._value)
#
# File ~/Documents/Forschungsprojekt III/code/.venv/lib/python3.13/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/Documents/Forschungsprojekt III/code/.venv/lib/python3.13/site-packages/jax/_src/array.py:689, in ArrayImpl._value(self)
#     687 if self._npy_value is None:
#     688   if self.is_fully_replicated:
# --> 689     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#     690     npy_value.flags.writeable = False
#     691     if did_copy:
#
# KeyboardInterrupt:

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
for fidelities, label in zip(fidelity_lists, fidelity_labels):
    ax1.plot(fidelities, label=label)
ax1.set_xlabel("Iteration")
ax1.set_ylabel("Fidelity")
ax1.set_title("Fidelity over Iterations")

ax2.plot([max(fidelities) for fidelities in fidelity_lists], label=label, marker="o", linestyle='None')

# legend in seperate figure
fig2, ax2 = plt.subplots(1,1, figsize=(6,4))
ax2.legend(*ax1.get_legend_handles_labels(), loc='center')
ax2.axis('off')
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %%
j_arr = jnp.arange(1, n)


J_theory = jnp.array([jnp.sqrt(j*(n-j)) for j in j_arr])

fig, ax = plt.subplots(1,1, figsize=(6,4))
ax.plot(j_arr, J_theory, label="theory", linestyle='dashed', marker=".")
for k, result in enumerate(best_result_each):
    J_meas = result.optimized_trainable_parameters[0][0]
    ax.plot(j_arr, J_meas, linestyle='-', marker=".")
ax.plot([],[],ls="-",color="grey",marker=".", label="optimized")
ax.set_xlabel("Coupling index j")
ax.set_ylabel("Coupling strength J_j")
ax.set_title("Optimized couplings vs. theoretical couplings")
ylims = ax.get_ylim()
ax.set_ylim(min(ylims[0]-0.1, 0),max(0, ylims[1]+0.1))
ax.legend()
#fig.savefig("couplings_n=6.png")

# %%
print(best_result.optimized_trainable_parameters[0][0])
# Out:
# [1.86933301 2.81340427 5.02630697 4.8108258  2.32224607]

# %% [markdown]
# ### Next, train a single architecture to work with arbitrary states

# %%
# To make it fair with the previous technique, we restrain the amount of training iterations
N_iter = 10

def reinitialize_transport_gates(initial_params):
    return Gate(
        gate = transport_unitary,
        initial_params=initial_params,
        param_constraints = [(0.0, 2*n)]*(n-1), # constraints for each coupling
        measurement_flag=False,
    )

result_each = []
for s in range(N_samples):
    print(f"Running sample {s}")
    system_params = [initialize_transport_gates(key=s)]

    for alpha in alphas:
        for phi in phis:
            print(f"    Running for alpha={alpha:.2f}, phi={phi:.2f}", end="...")

            rho_initial, rho_target = prepare_states(alpha, phi, i, n)

            # Training
            result = optimize_pulse(
                U_0=rho_initial,
                C_target=rho_target,
                system_params=system_params,
                num_time_steps=1,
                mode="no-measurement",
                goal="fidelity",
                max_iter=N_iter,
                convergence_threshold=1e-6,
                learning_rate=learning_rate,
                evo_type="density",
                batch_size=8,
                eval_batch_size=10,
            )

            print(f" Final fidelity: {result.final_fidelity:.2f}. Iterations: {result.iterations}")

            system_params = [ # Reinitialize with previously optimized parameters
                reinitialize_transport_gates(result.optimized_trainable_parameters[0][0])
            ]

    result_each.append(result)
# Out:
# Running sample 0
#     Running for alpha=0.00, phi=0.00... Final fidelity: 0.19. Iterations: 10
#     Running for alpha=0.00, phi=2.09... Final fidelity: 0.40. Iterations: 10
#     Running for alpha=0.00, phi=4.19... Final fidelity: 0.61. Iterations: 10
#     Running for alpha=0.00, phi=6.28... Final fidelity: 0.75. Iterations: 10
#     Running for alpha=0.25, phi=0.00... Final fidelity: 0.73. Iterations: 10
#     Running for alpha=0.25, phi=2.09... Final fidelity: 0.84. Iterations: 10
#     Running for alpha=0.25, phi=4.19... Final fidelity: 0.89. Iterations: 10
#     Running for alpha=0.25, phi=6.28... Final fidelity: 0.92. Iterations: 10
#     Running for alpha=0.50, phi=0.00... Final fidelity: 0.95. Iterations: 10
#     Running for alpha=0.50, phi=2.09... Final fidelity: 0.96. Iterations: 10
#     Running for alpha=0.50, phi=4.19... Final fidelity: 0.97. Iterations: 10
#     Running for alpha=0.50, phi=6.28... Final fidelity: 0.98. Iterations: 10
#     Running for alpha=0.75, phi=0.00... Final fidelity: 0.99. Iterations: 10
#     Running for alpha=0.75, phi=2.09... Final fidelity: 0.99. Iterations: 10
#     Running for alpha=0.75, phi=4.19... Final fidelity: 0.99. Iterations: 10
#     Running for alpha=0.75, phi=6.28... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=1.00, phi=0.00... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=2.09... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=4.19... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=6.28... Final fidelity: 1.00. Iterations: 2
# Running sample 1
#     Running for alpha=0.00, phi=0.00... Final fidelity: 0.22. Iterations: 10
#     Running for alpha=0.00, phi=2.09... Final fidelity: 0.39. Iterations: 10
#     Running for alpha=0.00, phi=4.19... Final fidelity: 0.59. Iterations: 10
#     Running for alpha=0.00, phi=6.28... Final fidelity: 0.77. Iterations: 10
#     Running for alpha=0.25, phi=0.00... Final fidelity: 0.89. Iterations: 10
#     Running for alpha=0.25, phi=2.09... Final fidelity: 0.91. Iterations: 10
#     Running for alpha=0.25, phi=4.19... Final fidelity: 0.92. Iterations: 10
#     Running for alpha=0.25, phi=6.28... Final fidelity: 0.93. Iterations: 10
#     Running for alpha=0.50, phi=0.00... Final fidelity: 0.95. Iterations: 10
#     Running for alpha=0.50, phi=2.09... Final fidelity: 0.95. Iterations: 10
#     Running for alpha=0.50, phi=4.19... Final fidelity: 0.96. Iterations: 10
#     Running for alpha=0.50, phi=6.28... Final fidelity: 0.97. Iterations: 10
#     Running for alpha=0.75, phi=0.00... Final fidelity: 0.99. Iterations: 10
#     Running for alpha=0.75, phi=2.09... Final fidelity: 0.99. Iterations: 10
#     Running for alpha=0.75, phi=4.19... Final fidelity: 0.99. Iterations: 10
#     Running for alpha=0.75, phi=6.28... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=1.00, phi=0.00... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=2.09... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=4.19... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=6.28... Final fidelity: 1.00. Iterations: 2
# Running sample 2
#     Running for alpha=0.00, phi=0.00... Final fidelity: 0.26. Iterations: 10
#     Running for alpha=0.00, phi=2.09... Final fidelity: 0.41. Iterations: 10
#     Running for alpha=0.00, phi=4.19... Final fidelity: 0.57. Iterations: 10
#     Running for alpha=0.00, phi=6.28... Final fidelity: 0.72. Iterations: 10
#     Running for alpha=0.25, phi=0.00... Final fidelity: 0.83. Iterations: 10
#     Running for alpha=0.25, phi=2.09... Final fidelity: 0.90. Iterations: 10
#     Running for alpha=0.25, phi=4.19... Final fidelity: 0.95. Iterations: 10
#     Running for alpha=0.25, phi=6.28... Final fidelity: 0.98. Iterations: 10
#     Running for alpha=0.50, phi=0.00... Final fidelity: 0.99. Iterations: 10
#     Running for alpha=0.50, phi=2.09... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=0.50, phi=4.19... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=0.50, phi=6.28... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=0.75, phi=0.00... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=0.75, phi=2.09... Final fidelity: 1.00. Iterations: 8
#     Running for alpha=0.75, phi=4.19... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=0.75, phi=6.28... Final fidelity: 1.00. Iterations: 8
#     Running for alpha=1.00, phi=0.00... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=2.09... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=4.19... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=6.28... Final fidelity: 1.00. Iterations: 2
# Running sample 3
#     Running for alpha=0.00, phi=0.00... Final fidelity: 0.23. Iterations: 10
#     Running for alpha=0.00, phi=2.09... Final fidelity: 0.32. Iterations: 10
#     Running for alpha=0.00, phi=4.19... Final fidelity: 0.41. Iterations: 10
#     Running for alpha=0.00, phi=6.28... Final fidelity: 0.50. Iterations: 10
#     Running for alpha=0.25, phi=0.00... Final fidelity: 0.58. Iterations: 10
#     Running for alpha=0.25, phi=2.09... Final fidelity: 0.64. Iterations: 10
#     Running for alpha=0.25, phi=4.19... Final fidelity: 0.69. Iterations: 10
#     Running for alpha=0.25, phi=6.28... Final fidelity: 0.73. Iterations: 10
#     Running for alpha=0.50, phi=0.00... Final fidelity: 0.81. Iterations: 10
#     Running for alpha=0.50, phi=2.09... Final fidelity: 0.84. Iterations: 10
#     Running for alpha=0.50, phi=4.19... Final fidelity: 0.86. Iterations: 10
#     Running for alpha=0.50, phi=6.28... Final fidelity: 0.86. Iterations: 10
#     Running for alpha=0.75, phi=0.00... Final fidelity: 0.93. Iterations: 10
#     Running for alpha=0.75, phi=2.09... Final fidelity: 0.94. Iterations: 10
#     Running for alpha=0.75, phi=4.19... Final fidelity: 0.95. Iterations: 10
#     Running for alpha=0.75, phi=6.28... Final fidelity: 0.96. Iterations: 10
#     Running for alpha=1.00, phi=0.00... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=2.09... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=4.19... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=6.28... Final fidelity: 1.00. Iterations: 2
# Running sample 4
#     Running for alpha=0.00, phi=0.00... Final fidelity: 0.00. Iterations: 10
#     Running for alpha=0.00, phi=2.09... Final fidelity: 0.01. Iterations: 10
#     Running for alpha=0.00, phi=4.19... Final fidelity: 0.02. Iterations: 10
#     Running for alpha=0.00, phi=6.28... Final fidelity: 0.04. Iterations: 10
#     Running for alpha=0.25, phi=0.00... Final fidelity: 0.12. Iterations: 10
#     Running for alpha=0.25, phi=2.09... Final fidelity: 0.18. Iterations: 10
#     Running for alpha=0.25, phi=4.19... Final fidelity: 0.27. Iterations: 10
#     Running for alpha=0.25, phi=6.28... Final fidelity: 0.36. Iterations: 10
#     Running for alpha=0.50, phi=0.00... Final fidelity: 0.55. Iterations: 10
#     Running for alpha=0.50, phi=2.09... Final fidelity: 0.64. Iterations: 10
#     Running for alpha=0.50, phi=4.19... Final fidelity: 0.73. Iterations: 10
#     Running for alpha=0.50, phi=6.28... Final fidelity: 0.82. Iterations: 10
#     Running for alpha=0.75, phi=0.00... Final fidelity: 0.93. Iterations: 10
#     Running for alpha=0.75, phi=2.09... Final fidelity: 0.96. Iterations: 10
#     Running for alpha=0.75, phi=4.19... Final fidelity: 0.98. Iterations: 10
#     Running for alpha=0.75, phi=6.28... Final fidelity: 1.00. Iterations: 10
#     Running for alpha=1.00, phi=0.00... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=2.09... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=4.19... Final fidelity: 1.00. Iterations: 2
#     Running for alpha=1.00, phi=6.28... Final fidelity: 1.00. Iterations: 2

# %%
j_arr = jnp.arange(1, n)


J_theory = jnp.array([jnp.sqrt(j*(n-j)) for j in j_arr])

fig, ax = plt.subplots(1,1, figsize=(6,4))
ax.plot(j_arr, J_theory, label="theory", linestyle='dashed', marker=".")
for k, result in enumerate(result_each):
    J_meas = result.optimized_trainable_parameters[0][0]
    ax.plot(j_arr, J_meas, linestyle='-', marker=".")
ax.plot([],[],ls="-",color="grey",marker=".", label="optimized")
ax.set_xlabel("Coupling index j")
ax.set_ylabel("Coupling strength J_j")
ax.set_title("Optimized couplings vs. theoretical couplings")
ylims = ax.get_ylim()
ax.set_ylim(min(ylims[0]-0.1, 0),max(0, ylims[1]+0.1))
ax.legend()
#fig.savefig("couplings_n=6.png")
